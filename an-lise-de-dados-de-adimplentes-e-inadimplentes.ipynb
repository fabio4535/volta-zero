# %% [markdown]
# ## **Análise de Dados de Adimplente e Inadimpletes**
#
# ### **Breve descrição do problema;**
#
# Em um mundo onde a gestão financeira é crucial para a sustentabilidade de indivíduos e empresas, compreender o comportamento de adimplentes e inadimplentes é uma questão de grande relevância. Este estudo tem como objetivo analisar padrões de comportamento financeiro a partir de um conjunto de dados detalhado, utilizando ferramentas de análise de dados e visualizações interativa
#
# [link](https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv). Os dados estão no formato CSV e contém informações sobre clientes de uma instituição financeira. Em especial, estamos interessados em explicar a segunda coluna, chamada de **default**, que indica se um cliente é adimplente(`default = 0`), ou inadimplente (`default = 1`), ou seja, queremos entender o porque um cliente deixa de honrar com suas dívidas baseado no comportamento de outros atributos, como salário, escolaridade e movimentação financeira. Uma descrição completa dos atributos está abaixo.
#
#
# ### **Código de importação de bibliotecas;**
# * import pandas as pd
# * import seaborn as sns
# * import matplotlib.pyplot as plt
# * import numpy as np
#
#
# ### **Dados Explorados;**
#
# https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv
#
# ### **Etapa de exploração;**
#
# Durante a etapa de exploração de dados, analisamos cada coluna e linha por linha para verificar a consistência das informações, tanto em relação aos números quanto ao formato geral dos dados. Identificamos que havia dois valores do tipo *float*, mas eles estavam no formato americano, utilizando ponto como separador decimal. No Brasil, utilizamos a vírgula como separador decimal, o que fez com que o *pandas* interpretasse esses valores como strings, atribuindo-lhes o tipo "object". Foi necessário converter esses valores para o tipo *float* para prosseguir com o tratamento adequado dos dados.
#
#
# ### **Etapa de limpeza e transformação;**
#
# Conseguimos converter os dados que estavam como "object" para o tipo *float*. Em seguida, realizamos a etapa de limpeza dos dados, descartando as linhas que não estavam preenchidas, ou seja, aquelas que continham valores nulos representados como "NaN". Esse processo foi essencial para garantir a consistência e a qualidade dos dados utilizados na análise.
#
# ### **Etapa de análise (com visualizações);**
#
# Na etapa de visualização, criamos cinco gráficos para tentar identificar os motivos que levaram algumas pessoas à inadimplência.
#
# Primeiramente, geramos um gráfico de barras para analisar a escolaridade dos clientes e verificar se era possível obter algum insight relevante. Contudo, não encontramos nenhuma relação significativa nesse aspecto.
#
# Em seguida, elaboramos outro gráfico de barras, desta vez com os salários anuais dos clientes, para investigar se havia alguma correlação entre o nível de renda e a inadimplência. Novamente, não obtivemos resultados úteis.
#
# No terceiro gráfico, exploramos as transações realizadas pelos clientes e, finalmente, identificamos um padrão. Descobrimos que a maioria dos inadimplentes estava em uma faixa de transações entre 20 e 80.
#
# Para aprofundar essa análise, criamos mais um gráfico, desta vez avaliando o valor das transações. Observamos que os inadimplentes se concentravam em uma faixa de valores entre 1.000 e 2.500, o que trouxe insights mais claros para o estudo.
#
#
# ### **Resumo dos insights gerados.**
#
# Nos dois últimos gráficos, descobrimos que clientes que realizam mais transações têm menor probabilidade de se tornarem inadimplentes.
#
# Identificamos que a faixa de valores entre 1.000 e 10.000 engloba tanto adimplentes quanto inadimplentes, enquanto a faixa entre 12.500 e 17.500 é composta predominantemente por clientes adimplentes.
#
# Com base nesses dados, podemos focar a análise em possíveis eventos relacionados à inadimplência na categoria de transações entre 1.000 e 10.000. Além disso, é possível desenvolver estratégias para ajudar esses clientes a evitar a inadimplência, promovendo maior estabilidade financeira.
#
#
# Ao final desta análise, ficou evidente que fatores como [Escolaridade, Salario Anual, Transações e Valor de Transações] têm papel significativo no comportamento financeiro. Compreender esses padrões não é apenas uma questão de dados, mas de tomar decisões mais inteligentes e compassivas, promovendo a saúde financeira de indivíduos e organizações.
#
#
# Gostaria de expressar minha gratidão ao professor André, cujo compromisso com o ensino e a orientação transformadora foram essenciais para a conclusão deste trabalho. Seu entusiasmo e dedicação inspiram a todos que têm o privilégio de aprender com ele.
#
# Espero que esta análise inspire reflexões e contribua para novas discussões sobre gestão de crédito e análise de dados. Estou à disposição para colaborar e aprender mais sobre este fascinante universo. Vamos nos conectar!

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#
#   <li>Exploração de dados.</li>
#   <li>Transformação e limpeza de dados.</li>
#   <li>Visualização de dados.</li>
#
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# [link](https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv). Os dados estão no formato CSV e contém informações sobre clientes de uma instituição financeira. Em especial, estamos interessados em explicar a segunda coluna, chamada de **default**, que indica se um cliente é adimplente(`default = 0`), ou inadimplente (`default = 1`), ou seja, queremos entender o porque um cliente deixa de honrar com suas dívidas baseado no comportamento de outros atributos, como salário, escolaridade e movimentação financeira. Uma descrição completa dos atributos está abaixo.

# %% [markdown]
# ## 2\. Exploração de Dados

# %% [markdown]
# > O atributo de interesse (`default`) é conhecido como **variável resposta** ou **variável dependente**, já os demais atributos que buscam explicá-la (`idade`, `salário`, etc.) são conhecidas como **variáveis explicatívas**, **variáveis independentes** ou até **variáveis preditoras**.

# %% [markdown]
# | Coluna  | Descrição |
# | ------- | --------- |
# | id      | Número da conta |
# | default | Indica se o cliente é adimplente (0) ou inadimplente (1) |
# | idade   | --- |
# | sexo    | --- |
# | depedentes | --- |
# | escolaridade | --- |
# | estado_civil | --- |
# | salario_anual | Faixa do salario mensal multiplicado por 12 |
# | tipo_cartao | Categoria do cartao: blue, silver, gold e platinium |
# | meses_de_relacionamento | Quantidade de meses desde a abertura da conta |
# | qtd_produtos | Quantidade de produtos contratados |
# | iteracoes_12m | Quantidade de iteracoes com o cliente no último ano |
# | meses_inatico_12m | Quantidade de meses que o cliente ficou inativo no último ano |
# | limite_credito | Valor do limite do cartão de crédito |
# | valor_transacoes_12m | Soma total do valor das transações no cartão de crédito no último ano |
# | qtd_transacoes_12m | Quantidade total de transações no cartão de crédito no último ano |

# %% [markdown]
# Vamos começar lendos os dados num dataframe `pandas`.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv', na_values='na')

# %%
df.head(n=10)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
# 5  713061558        0     44    M            2             mestrado
# 6  810347208        0     51    M            4                  NaN
# 7  818906208        0     32    M            0         ensino medio
# 8  710930508        0     37    M            3  sem educacao formal
# 9  719661558        0     48    M            2             mestrado
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# ...

# %% [markdown]
# Com o dados em mãos, vamos conhecer um pouco melhor a estrutura do nosso conjunto de dados.

# %% [markdown]
# ### **2.1. Estrutura**

# %%
df.shape # retorna uma tupla (qtd linhas, qtd colunas)
# Out:
# (10127, 16)

# %%
df[df['default'] == 0].shape
# Out:
# (8500, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1627, 16)

# %%
qtd_total, _ = df.shape
qtd_adimplentes, _ = df[df['default'] == 0].shape
qtd_inadimplentes, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão clientes adimplentes é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
# Out:
# A proporcão clientes adimplentes é de 83.93%
# A proporcão clientes inadimplentes é de 16.07%

# %% [markdown]
# ### **2.2. Schema**

# %%
df.head(n=5)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
#  - Colunas e seus respectivos tipos de dados.

# %%
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %% [markdown]
#  - Atributos **categóricos**.

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                       count unique             top  freq
# sexo                  10127      2               F  5358
# escolaridade           8608      5        mestrado  3128
# estado_civil           9378      3          casado  4687
# salario_anual          9015      5  menos que $40K  3561
# tipo_cartao           10127      4            blue  9436
# limite_credito        10127   9272        1.438,21    11
# valor_transacoes_12m  10127  10035        3.851,51     3

# %% [markdown]
#  - Atributos **numéricos**.

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count       mean        std   min   25%   50%  \
# default                  10127.0   0.160660   0.367235   0.0   0.0   0.0
# idade                    10127.0  46.325960   8.016814  26.0  41.0  46.0
# dependentes              10127.0   2.346203   1.298908   0.0   1.0   2.0
# meses_de_relacionamento  10127.0  35.928409   7.986416  13.0  31.0  36.0
# qtd_produtos             10127.0   3.812580   1.554408   1.0   3.0   4.0
# iteracoes_12m            10127.0   2.455317   1.106225   0.0   2.0   2.0
# meses_inativo_12m        10127.0   2.341167   1.010622   0.0   2.0   2.0
# qtd_transacoes_12m       10127.0  64.858695  23.472570  10.0  45.0  67.0
#
#                           75%    max
# default                   0.0    1.0
# idade                    52.0   73.0
# dependentes               3.0    5.0
# meses_de_relacionamento  40.0   56.0
# qtd_produtos              5.0    6.0
# iteracoes_12m             3.0    6.0
# meses_inativo_12m         3.0    6.0
# ...

# %% [markdown]
# ### **2.3. Dados faltantes**

# %% [markdown]
# Dados faltantes podem ser:
#
#  - Vazios (`""`);
#  - Nulos (`None`);
#  - Não disponíveis ou aplicaveis (`na`, `NA`, etc.);
#  - Não numérico (`nan`, `NaN`, `NAN`, etc).

# %%
df.head()
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
# Podemos verificar quais colunas possuem dados faltantes.

# %%
df.isna().any()
# Out:
# id                         False
# default                    False
# idade                      False
# sexo                       False
# dependentes                False
# escolaridade                True
# estado_civil                True
# salario_anual               True
# tipo_cartao                False
# meses_de_relacionamento    False
# qtd_produtos               False
# iteracoes_12m              False
# meses_inativo_12m          False
# limite_credito             False
# valor_transacoes_12m       False
# qtd_transacoes_12m         False
# dtype: bool

# %% [markdown]
#  - A função abaixo levanta algumas estatisticas sobre as colunas dos dados faltantes.

# %%
def stats_dados_faltantes(df: pd.DataFrame) -> None:

  stats_dados_faltantes = []
  for col in df.columns:
    if df[col].isna().any():
      qtd, _ = df[df[col].isna()].shape
      total, _ = df.shape
      dict_dados_faltantes = {col: {'quantidade': qtd, "porcentagem": round(100 * qtd/total, 2)}}
      stats_dados_faltantes.append(dict_dados_faltantes)

  for stat in stats_dados_faltantes:
    print(stat)

# %%
stats_dados_faltantes(df=df)
# Out:
# {'escolaridade': {'quantidade': 1519, 'porcentagem': 15.0}}
# {'estado_civil': {'quantidade': 749, 'porcentagem': 7.4}}
# {'salario_anual': {'quantidade': 1112, 'porcentagem': 10.98}}

# %%
stats_dados_faltantes(df=df[df['default'] == 0])
# Out:
# {'escolaridade': {'quantidade': 1263, 'porcentagem': 14.86}}
# {'estado_civil': {'quantidade': 620, 'porcentagem': 7.29}}
# {'salario_anual': {'quantidade': 925, 'porcentagem': 10.88}}

# %%
stats_dados_faltantes(df=df[df['default'] == 1])
# Out:
# {'escolaridade': {'quantidade': 256, 'porcentagem': 15.73}}
# {'estado_civil': {'quantidade': 129, 'porcentagem': 7.93}}
# {'salario_anual': {'quantidade': 187, 'porcentagem': 11.49}}

# %% [markdown]
# ## 3\. Transformação e limpeza de dados

# %% [markdown]
# Agora que conhecemos melhor a natureza do nosso conjunto de dados, vamos conduzir uma atividade conhecida como *data wrangling* que consiste na transformação e limpeza dos dados do conjunto para que possam ser melhor analisados. Em especial, vamos remover:
#
#  - Corrigir o *schema* das nossas colunas;
#  - Remover os dados faltantes.

# %% [markdown]
# ### **3.1. Correção de schema**

# %% [markdown]
# Na etapa de exploração, notamos que as colunas **limite_credito** e **valor_transacoes_12m** estavam sendo interpretadas como colunas categóricas (`dtype = object`).

# %%
df[['limite_credito', 'valor_transacoes_12m']].dtypes
# Out:
# limite_credito          object
# valor_transacoes_12m    object
# dtype: object

# %%
df[['limite_credito', 'valor_transacoes_12m']].head(n=5)
# Out:
#   limite_credito valor_transacoes_12m
# 0      12.691,51             1.144,90
# 1       8.256,96             1.291,45
# 2       3.418,56             1.887,72
# 3       3.313,03             1.171,56
# 4       4.716,22               816,08

# %% [markdown]
# Vamos criar uma função `lambda` para limpar os dados. Mas antes, vamos testar sua aplicação através do método funcional `map`:

# %%
fn = lambda valor: float(valor.replace(".", "").replace(",", "."))

valores_originais = ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
valores_limpos = list(map(fn, valores_originais))

print(valores_originais)
print(valores_limpos)
# Out:
# ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
# [12691.51, 8256.96, 3418.56, 3313.03, 4716.22]

# %% [markdown]
# Com a função `lambda` de limpeza pronta, basta aplica-la nas colunas de interesse.

# %%
df['valor_transacoes_12m'] = df['valor_transacoes_12m'].apply(fn)
df['limite_credito'] = df['limite_credito'].apply(fn)

# %% [markdown]
# Vamos descrever novamente o *schema*:

# %%
df.dtypes
# Out:
# id                           int64
# default                      int64
# idade                        int64
# sexo                        object
# dependentes                  int64
# escolaridade                object
# estado_civil                object
# salario_anual               object
# tipo_cartao                 object
# meses_de_relacionamento      int64
# qtd_produtos                 int64
# iteracoes_12m                int64
# meses_inativo_12m            int64
# limite_credito             float64
# valor_transacoes_12m       float64
# qtd_transacoes_12m           int64
# dtype: object

# %% [markdown]
#  - Atributos **categóricos**.

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                count unique             top  freq
# sexo           10127      2               F  5358
# escolaridade    8608      5        mestrado  3128
# estado_civil    9378      3          casado  4687
# salario_anual   9015      5  menos que $40K  3561
# tipo_cartao    10127      4            blue  9436

# %% [markdown]
#  - Atributos **numéricos**.

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count         mean          std      min       25%  \
# default                  10127.0     0.160660     0.367235     0.00     0.000
# idade                    10127.0    46.325960     8.016814    26.00    41.000
# dependentes              10127.0     2.346203     1.298908     0.00     1.000
# meses_de_relacionamento  10127.0    35.928409     7.986416    13.00    31.000
# qtd_produtos             10127.0     3.812580     1.554408     1.00     3.000
# iteracoes_12m            10127.0     2.455317     1.106225     0.00     2.000
# meses_inativo_12m        10127.0     2.341167     1.010622     0.00     2.000
# limite_credito           10127.0  8632.440165  9088.788041  1438.00  2555.355
# valor_transacoes_12m     10127.0  4404.583047  3397.128078   510.16  2155.825
# qtd_transacoes_12m       10127.0    64.858695    23.472570    10.00    45.000
#
#                              50%        75%       max
# default                     0.00      0.000      1.00
# ...

# %% [markdown]
# ### **3.2. Remoção de dados faltantes**

# %% [markdown]
# Como o pandas está ciente do que é um dados faltante, a remoção das linhas problemáticas é trivial.

# %%
df.dropna(inplace=True)

# %% [markdown]
# Vamos analisar a estrutura dos dados novamente.

# %%
df.shape
# Out:
# (7081, 16)

# %%
df[df['default'] == 0].shape
# Out:
# (5968, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1113, 16)

# %%
qtd_total_novo, _ = df.shape
qtd_adimplentes_novo, _ = df[df['default'] == 0].shape
qtd_inadimplentes_novo, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão adimplentes ativos é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes adimplentes é de {round(100 * qtd_adimplentes_novo / qtd_total_novo, 2)}%")
print("")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes inadimplentes é de {round(100 * qtd_inadimplentes_novo / qtd_total_novo, 2)}%")
# Out:
# A proporcão adimplentes ativos é de 83.93%
# A nova proporcão de clientes adimplentes é de 84.28%
#
# A proporcão clientes inadimplentes é de 16.07%
# A nova proporcão de clientes inadimplentes é de 15.72%

# %% [markdown]
# ## 4\. Visualização de dados

# %% [markdown]
# Os dados estão prontos, vamos criar diversas visualizações para correlacionar variáveis explicativas com a variável resposta para buscar entender qual fator leva um cliente a inadimplencia. E para isso, vamos sempre comparar a base com todos os clientes com a base de adimplentes e inadimplentes.

# %% [markdown]
# Começamos então importando os pacotes de visualização e separando os clientes adimplentes e inadimplentes

# %%
sns.set_style("whitegrid")

# %%
df_adimplente = df[df['default'] == 0]

# %%
df_inadimplente = df[df['default'] == 1]

# %% [markdown]
# ### **4.1. Visualizações categóricas**

# %% [markdown]
# Nesta seção, vamos visualizar a relação entre a variável resposta **default** com os atributos categóricos.

# %%
df.select_dtypes('object').head(n=5)
# Out:
#   sexo         escolaridade estado_civil   salario_anual tipo_cartao
# 0    M         ensino medio       casado     $60K - $80K        blue
# 1    F             mestrado     solteiro  menos que $40K        blue
# 2    M             mestrado       casado    $80K - $120K        blue
# 4    M  sem educacao formal       casado     $60K - $80K        blue
# 5    M             mestrado       casado     $40K - $60K        blue

# %% [markdown]
#  - Escolaridade

# %%
coluna = 'escolaridade'
titulos = ['Escolaridade dos Clientes', 'Escolaridade dos Clientes Adimplentes', 'Escolaridade dos Clientes Inadimplentes']

eixo = 0
max_y = 0
max_freq = df.select_dtypes('object').describe()[coluna]['freq'] * 1.1  # Renomeado para evitar conflito com a função max()

figura, eixos = plt.subplots(1, 3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:
    df_to_plot = dataframe[coluna].value_counts().reset_index()  # Cria um novo DataFrame com as contagens
    df_to_plot.columns = [coluna, 'frequencia_absoluta']
    df_to_plot.sort_values(by=[coluna], inplace=True)
    
    f = sns.barplot(x=coluna, y='frequencia_absoluta', data=df_to_plot, ax=eixos[eixo])
    f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
    f.set_xticks(range(len(df_to_plot[coluna])))  # Define as posições dos ticks
    f.set_xticklabels(df_to_plot[coluna], rotation=90)  # Define os rótulos
    _, max_y_f = f.get_ylim()
    max_y = max_y_f if max_y_f > max_y else max_y
    f.set(ylim=(0, max_y))
    eixo += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ANTIGO

# %% [markdown]
#  - Salário Anual

# %%
coluna = 'salario_anual'
titulos = ['Salário Anual dos Clientes', 'Salário Anual dos Clientes Adimplentes', 'Salário Anual dos Clientes Inadimplentes']

eixo = 0
max_y = 0
max_freq = df.select_dtypes('object').describe()[coluna]['freq'] * 1.1  # Renomeado para evitar conflito com a função max()

figura, eixos = plt.subplots(1, 3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:
    df_to_plot = dataframe[coluna].value_counts().reset_index()  # Cria um novo DataFrame com as contagens
    df_to_plot.columns = [coluna, 'frequencia_absoluta']
    df_to_plot.sort_values(by=[coluna], inplace=True)
    
    f = sns.barplot(x=coluna, y='frequencia_absoluta', data=df_to_plot, ax=eixos[eixo])
    f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
    f.set_xticks(range(len(df_to_plot[coluna])))  # Define as posições dos ticks
    f.set_xticklabels(df_to_plot[coluna], rotation=90)  # Define os rótulos
    _, max_y_f = f.get_ylim()
    max_y = max_y_f if max_y_f > max_y else max_y
    f.set(ylim=(0, max_y))
    eixo += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ANTIGO

# %% [markdown]
# ### **4.2. Visualizações numéricas**

# %% [markdown]
# Nesta seção, vamos visualizar a relação entre a variável resposta **default** com os atributos numéricos.

# %%
df.drop(['id', 'default'], axis=1).select_dtypes('number').head(n=5)
# Out:
#    idade  dependentes  meses_de_relacionamento  qtd_produtos  iteracoes_12m  \
# 0     45            3                       39             5              3
# 1     49            5                       44             6              2
# 2     51            3                       36             4              0
# 4     40            3                       21             5              0
# 5     44            2                       36             3              2
#
#    meses_inativo_12m  limite_credito  valor_transacoes_12m  qtd_transacoes_12m
# 0                  1        12691.51               1144.90                  42
# 1                  1         8256.96               1291.45                  33
# 2                  1         3418.56               1887.72                  20
# 4                  1         4716.22                816.08                  28
# 5                  1         4010.69               1088.07                  24

# %% [markdown]
#  - Quantidade de Transações nos Últimos 12 Meses

# %%
coluna = 'qtd_transacoes_12m'
titulos = ['Qtd. de Transações no Último Ano', 'Qtd. de Transações no Último Ano de Adimplentes', 'Qtd. de Transações no Último Ano de Inadimplentes']

import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)

# Criar cópias explícitas dos DataFrames para evitar warnings
df = df.copy()
df_adimplente = df_adimplente.copy()
df_inadimplente = df_inadimplente.copy()

# Tratamento para NaN e Inf
for dataframe in [df, df_adimplente, df_inadimplente]:
   dataframe.loc[:, coluna] = pd.to_numeric(dataframe[coluna], errors='coerce') # Garante valores numéricos
   dataframe.dropna(subset=[coluna], inplace=True) # Remove NaN
   dataframe.loc[:, coluna] = dataframe[coluna].replace([np.inf, -np.inf], np.nan) # Substitui Inf por NaN
   dataframe.dropna(subset=[coluna], inplace=True) # Remove Inf após substituir

# Configuração dos gráficos
eixo = 0
max_y = 0
figura, eixos = plt.subplots(1, 3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:
   f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
   f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

   # Ajuste de escala do eixo y para que todos os gráficos tenham a mesma altura
   _, max_y_f = f.get_ylim()
   max_y = max(max_y, max_y_f)
   f.set(ylim=(0, max_y))

   eixo += 1

plt.tight_layout()
plt.show()

# %% [markdown]
#  - Valor das Transações nos Últimos 12 Meses

# %%
coluna = 'valor_transacoes_12m'
titulos = ['Valor das Transações no Último Ano', 'Valor das Transações no Último Ano de Adimplentes', 'Valor das Transações no Último Ano de Inadimplentes']

# Garantindo que valores NaN e Inf sejam removidos ou substituídos
coluna = 'valor_transacoes_12m'
titulos = [
   'Valor das Transações no Último Ano', 
   'Valor das Transações no Último Ano de Adimplentes', 
   'Valor das Transações no Último Ano de Inadimplentes'
]

# Criar cópias explícitas dos DataFrames para evitar warnings
df = df.copy()
df_adimplente = df_adimplente.copy()
df_inadimplente = df_inadimplente.copy()

# Tratamento para NaN e Inf
for dataframe in [df, df_adimplente, df_inadimplente]:
   dataframe.loc[:, coluna] = pd.to_numeric(dataframe[coluna], errors='coerce') # Garante valores numéricos
   dataframe.dropna(subset=[coluna], inplace=True) # Remove NaN
   dataframe.loc[:, coluna] = dataframe[coluna].replace([np.inf, -np.inf], np.nan) # Substitui Inf por NaN
   dataframe.dropna(subset=[coluna], inplace=True) # Remove Inf após substituir

# Configuração dos gráficos
eixo = 0
max_y = 0
figura, eixos = plt.subplots(1, 3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:
   f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
   f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

   # Ajuste de escala do eixo y para que todos os gráficos tenham a mesma altura
   _, max_y_f = f.get_ylim()
   max_y = max(max_y, max_y_f)
   f.set(ylim=(0, max_y))

   eixo += 1

plt.tight_layout()
plt.show()

# %% [markdown]
#  - Valor de Transações nos Últimos 12 Meses x Quantidade de Transações nos Últimos 12 Meses

# %%
f = sns.relplot(x='valor_transacoes_12m', y='qtd_transacoes_12m', data=df, hue='default')
_ = f.set(
    title='Relação entre Valor e Quantidade de Transações no Último Ano',
    xlabel='Valor das Transações no Último Ano',
    ylabel='Quantidade das Transações no Último Ano'
  )
